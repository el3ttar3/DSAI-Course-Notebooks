# %%
import pandas as pd

# %%
import numpy as np

# %%
row_data = pd.read_csv('amazon.csv')
pd.set_option('display.width', 1)
pd.set_option('display.max_colwidth', 20)
row_data.sample(10)
# Out:
#       product_id  \
# 1023  B00H47GVGY
# 134   B082T6GVG9
# 1403  B07B5XJ572
# 1196  B07DXRGWDJ
# 610   B00ZYLMQH0
# 1123  B01N1XVVLC
# 854   B00VA7YYUO
# 446   B08VB2CMR3
# 186   B0B8SSC5D9
# 781   B09P564ZTJ
#
#              product_name  \
# 1023  USHA Quartz Room...
# 134   AmazonBasics New...
# 1403  iBELL MPK120L Pr...
# 1196  Philips Handheld...
# 610   Dell KB216 Wired...
# 1123  Bajaj OFR Room H...
# 854   Apsara Platinum ...
# 446   OPPO A74 5G (Flu...
# 186   AmazonBasics USB...
# 781   Wembley LCD Writ...
#
#                  category  \
# 1023  Home&Kitchen|Hea...
# 134   Computers&Access...
# 1403  Home&Kitchen|Kit...
# 1196  Home&Kitchen|Kit...
# 610   Computers&Access...
# 1123  Home&Kitchen|Hea...
# 854   Home&Kitchen|Cra...
# 446   Electronics|Mobi...
# 186   Computers&Access...
# 781   Computers&Access...
#
#      discounted_price  \
# 1023           ₹1,199
# 134              ₹689
# 1403           ₹1,456
# 1196           ₹4,280
# 610              ₹549
# ...

# %%
duplicated = row_data[row_data.duplicated()]
duplicated.head(10)
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, discounted_price, actual_price, discount_percentage, rating, rating_count, about_product, user_id, user_name, review_id, review_title, review_content, img_link, product_link]
# Index: []

# %%
missing_value_count = row_data.isnull().sum()
print(f'missing value sum is \n {missing_value_count}')
# Out:
# missing value sum is
#  product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
df=pd.DataFrame(missing_value_count)
df.transpose()
# Out:
#    product_id  \
# 0           0
#
#    product_name  \
# 0             0
#
#    category  \
# 0         0
#
#    discounted_price  \
# 0                 0
#
#    actual_price  \
# 0             0
#
#    discount_percentage  \
# 0                    0
#
#    rating  \
# 0       0
#
#    rating_count  \
# 0             2
#
#    about_product  \
# 0              0
#
#    user_id  \
# 0        0
#
#    user_name  \
# 0          0
#
#    review_id  \
# 0          0
#
#    review_title  \
# 0             0
#
#    review_content  \
# 0               0
#
#    img_link  \
# 0         0
#
#    product_link
# 0             0
