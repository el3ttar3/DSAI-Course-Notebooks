# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = px.data.gapminder() # Built-in dataset
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
filltered_data = px.data.gapminder().query(" continent == 'Asia' ")
filltered_data
# Out:
#           country continent  year  lifeExp       pop    gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106       AFG
# ...           ...       ...   ...      ...       ...          ...       ...
# 1675  Yemen, Rep.      Asia  1987   52.922  11219340  1971.741538       YEM
# 1676  Yemen, Rep.      Asia  1992   55.599  13367997  1879.496673       YEM
# 1677  Yemen, Rep.      Asia  1997   58.020  15826497  2117.484526       YEM
# 1678  Yemen, Rep.      Asia  2002   60.308  18701257  2234.820827       YEM
# 1679  Yemen, Rep.      Asia  2007   62.698  22211743  2280.769906       YEM
#
#       iso_num
# 0           4
# 1           4
# ...

# %%
canada = px.data.gapminder().query(" country == 'Canada' ")
canada = canada.reset_index(drop = "true")
canada
# Out:
#    country continent  year  lifeExp       pop    gdpPercap iso_alpha  iso_num
# 0   Canada  Americas  1952   68.750  14785584  11367.16112       CAN      124
# 1   Canada  Americas  1957   69.960  17010154  12489.95006       CAN      124
# 2   Canada  Americas  1962   71.300  18985849  13462.48555       CAN      124
# 3   Canada  Americas  1967   72.130  20819767  16076.58803       CAN      124
# 4   Canada  Americas  1972   72.880  22284500  18970.57086       CAN      124
# 5   Canada  Americas  1977   74.210  23796400  22090.88306       CAN      124
# 6   Canada  Americas  1982   75.760  25201900  22898.79214       CAN      124
# 7   Canada  Americas  1987   76.860  26549700  26626.51503       CAN      124
# 8   Canada  Americas  1992   77.950  28523502  26342.88426       CAN      124
# 9   Canada  Americas  1997   78.610  30305843  28954.92589       CAN      124
# 10  Canada  Americas  2002   79.770  31902268  33328.96507       CAN      124
# ...
