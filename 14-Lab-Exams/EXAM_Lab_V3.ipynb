# %%
# !pip install alibi
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.inspection import PartialDependenceDisplay, permutation_importance
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from alibi.explainers import PartialDependence, plot_pd

# %%
df = pd.read_csv('/content/bank_full.csv', sep = ';')

df.y.value_counts()
# Out:
# y
# no     39922
# yes     5289
# Name: count, dtype: int64

# %%
y = df["y"].map({"no":0, "yes":1})
X = df.drop("y", axis=1)

# %%
X.drop("duration", inplace=True, axis=1)
num_features = ["age", "campaign", "pdays", "previous", "emp.var.rate",
                "cons.price.idx", "cons.conf.idx","euribor3m", "nr.employed"]

cat_features = ["job", "marital", "education","default", "housing", "loan",
                "contact", "month", "day_of_week", "poutcome"]

# %%
df_encoded = df.copy()
label_encoders = {}
for column in df_encoded.select_dtypes(include='object').columns:
    le = LabelEncoder()
    df_encoded[column] = le.fit_transform(df_encoded[column])
    label_encoders[column] = le

# Prepare features and target
X = df_encoded.drop("y", axis=1)
y = df_encoded["y"]
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
df_encoded.dtypes
# Out:
# age          int64
# job          int64
# marital      int64
# education    int64
# default      int64
# balance      int64
# housing      int64
# loan         int64
# contact      int64
# day          int64
# month        int64
# duration     int64
# campaign     int64
# pdays        int64
# previous     int64
# poutcome     int64
# y            int64
# dtype: object

# %%
# Prepare features and target
X = df_encoded.drop("y", axis=1)
y = df_encoded["y"]
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Train RF Classifier (0.5 points)

# %%
RF = RandomForestClassifier()
model_rf = RF.fit(X_train, y_train)
y_hat = model_rf.predict(X_test)

# %% [markdown]
# ##Plot PDB and ICE for two features (1 points, 0.25 for each plot), explian whether PDB and ICE for each feature is confirmimg each other or not, and why in both cases. (1 point)

# %%
prediction_fn = lambda x: predictor.predict(preprocessor.transform(X_train))

# define explainer
explainer = PartialDependence(predictor=prediction_fn,
                              feature_names=feature_names,
                              target_names=target_names,
                              categorical_names=categorical_names)
exp = explainer.explain(X=X_train,
                        features=num_features[0:2],
                        kind='average')
plot_pd(exp=exp,
        n_cols=3,
        sharey='row',
        fig_kw={'figheight': 10, 'figwidth': 15});
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-2244a05fc993> in <cell line: 0>()
#       3 # define explainer
#       4 explainer = PartialDependence(predictor=prediction_fn,
# ----> 5                               feature_names=feature_names,
#       6                               target_names=target_names,
#       7                               categorical_names=categorical_names)
#
# NameError: name 'feature_names' is not defined

# %% [markdown]
# ##Plot ALE plot for three feature in a different notebook to avoid installation problems and corruption of this notebook (1 point) , explain the results (1 points)

# %% [markdown]
# ## Perform Lime for one instance (1 point), explain the three parts of the output (1 point)

# %% [markdown]
# ##Plot SHAP values summary plot for all features (0.5), what is the most important 3 features? why? (0.5 points), what is the color gradient telling you? (0.5 points)

# %% [markdown]
# ## plot shap interaction plot for two features (1 point), explain the interaction (1 point)
